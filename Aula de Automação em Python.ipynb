# %% [markdown]
# Intensivão de Python [Aula 1] 09/01/2023 @HashtagProgramacao
#
# # Automação de Sistemas e Processos com Python - Amanda Amaral
#
# Código para fazer importação do arquivo PYAUTOGUI caso não esteja usando o JUPYTER  !pip install pyautogui

# %% [markdown]
# #Comando essênciais do comando pyautogui
#
#  #pyautogui.click -> clicar
#  #pyautogui.press -> apertar 1 tecla
#  #pyautogui.hotkey -> conjunto de teclas
#  #pyautogui.write -> escreve um texto

# %%
#importação das Bibliotecas abaixo:
import pyautogui as pa
import pyperclip as pc
import time

# %%
#Passo 01 - Entrar no sistema da empresa (Link Driver)
#https://drive.google.com/drive/u/0/folders/19xTs7ZPE1qTX0cQgLEjZZPPhjY2yvrDG

pa.hotkey ('ctrl','t')
time.sleep(3)
pc.copy ('https://drive.google.com/drive/u/0/folders/19xTs7ZPE1qTX0cQgLEjZZPPhjY2yvrDG')
pa.hotkey ('ctrl','v')
pa.press('enter')
time.sleep(3)

#Passo 02 - Fazer Download Arquivo

pa.click(x=416, y=291 ,clicks =1)
time.sleep(4)
pa.click(x=1165, y=188, clicks =1)
time.sleep(4)
pa.click(x=1013, y=558, clicks =1)

# %%
#Passo 03-Calcular os indicadores
import pandas as pd

tabela = pd.read_excel(r'C:\Users\dinho\OneDrive\Área de Trabalho\Intensivo Python\Aula01\Exportar\Vendas - Dez.xlsx')

display(tabela)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
faturamento = tabela['Valor Final'].sum()
quantidade = tabela['Quantidade'].sum()
display(faturamento)
display(quantidade)
# Out:
# 2917311
# 15227

# %%
#Passo 05 - Enviar o email com o cálculo
import pyautogui as pa
import pyperclip as pc
import time

#Passo 01- abrir a aba do email 
pa.hotkey('ctrl','t')
time.sleep (4)
pa.click(x=1156,y=137, clicks =1)
time.sleep (3)
pa.click(x=1156,y=137, clicks =1)

#Passo 02 -clicar botao escrever
pa.click(x=111, y=198, clicks =1)
time.sleep(2)
# preencher as informações do e-mail
pa.write('dinhoka.teste@gmail.com')
pa.press('tab')
time.sleep(2)
pa.write('Fazendo teste')
pa.press('tab')
time.sleep(2)


texto=f"""
Prezados,

Segue relatório de vendas.
Faturamento: R${faturamento:,.2f}
Quantidade de produtos vendidos: {quantidade:,}

Qualquer dúvida estou à disposição.
Att.,
Amanda
"""

pc.copy(texto)
pa.hotkey("ctrl", "v")
time.sleep(2)
pa.hotkey("ctrl", "enter")

# formatação dos números (moeda, dinheiro)

# enviar o e-mail
#pyautogui.click -> clicar
#pyautogui.press -> apertar 1 tecla
#pyautogui.hotkey -> conjunto de teclas
#pyautogui.write -> escreve um texto

# %%
#Código para localizar o ponto do Mouse
import time
time.sleep(5)
print(pa.position())
# Out:
# Point(x=356, y=254)
